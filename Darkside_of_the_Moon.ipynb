# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
import pandas as pd
ems = pd.read_csv('Ems_data.csv')
low_memory=False
ems.dtypes
# Out:
# CAD_INCIDENT_ID                     int64
# INCIDENT_DATETIME                  object
# INITIAL_CALL_TYPE                  object
# INITIAL_SEVERITY_LEVEL_CODE         int64
# FINAL_CALL_TYPE                    object
# FINAL_SEVERITY_LEVEL_CODE           int64
# FIRST_ASSIGNMENT_DATETIME          object
# VALID_DISPATCH_RSPNS_TIME_INDC     object
# DISPATCH_RESPONSE_SECONDS_QY        int64
# FIRST_ACTIVATION_DATETIME          object
# FIRST_ON_SCENE_DATETIME            object
# VALID_INCIDENT_RSPNS_TIME_INDC     object
# INCIDENT_RESPONSE_SECONDS_QY      float64
# INCIDENT_TRAVEL_TM_SECONDS_QY     float64
# FIRST_TO_HOSP_DATETIME             object
# FIRST_HOSP_ARRIVAL_DATETIME        object
# INCIDENT_CLOSE_DATETIME            object
# HELD_INDICATOR                     object
# INCIDENT_DISPOSITION_CODE         float64
# BOROUGH                            object
# INCIDENT_DISPATCH_AREA             object
# ZIPCODE                           float64
# POLICEPRECINCT                    float64
# CITYCOUNCILDISTRICT               float64
# COMMUNITYDISTRICT                 float64
# COMMUNITYSCHOOLDISTRICT           float64
# CONGRESSIONALDISTRICT             float64
# REOPEN_INDICATOR                   object
# SPECIAL_EVENT_INDICATOR            object
# STANDBY_INDICATOR                  object
# TRANSFER_INDICATOR                 object
# dtype: object

# %%
ems = ems[['INCIDENT_DATETIME', 'INITIAL_CALL_TYPE', 'INITIAL_SEVERITY_LEVEL_CODE', 'FINAL_CALL_TYPE', 'BOROUGH', 'ZIPCODE']]

# %%
ems.tail()
# Out:
#               INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 8557843  12/31/2018 09:22:44 PM             OTHER
# 8557844  12/31/2018 10:12:43 PM              SHOT
# 8557845  12/31/2018 10:33:43 PM             OTHER
# 8557846  12/31/2018 11:00:43 PM             OTHER
# 8557847  12/31/2018 11:31:55 PM            UNKNOW
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 8557843                            6           OTHER
# 8557844                            3            SHOT
# 8557845                            6           OTHER
# 8557846                            6           OTHER
# 8557847                            4          UNKNOW
#
#                           BOROUGH  ZIPCODE
# 8557843                 MANHATTAN  10027.0
# 8557844                     BRONX  10466.0
# 8557845                     BRONX  10462.0
# 8557846                  BROOKLYN  11207.0
# 8557847  RICHMOND / STATEN ISLAND  10310.0

# %%
#date_format = "%Y-%m-%dT%H:%M:%S.%f"
#s= datetime.strptime(ems['INCIDENT_DATETIME'], date_format)

#ems = ems.ems(400)
ems['INCIDENT_DATETIME'] = pd.to_datetime(ems['INCIDENT_DATETIME'])
ems = ems.astype({'INCIDENT_DATETIME': 'datetime64'})
ems.dtypes
# Out:
# CAD_INCIDENT_ID                            int64
# INCIDENT_DATETIME                 datetime64[ns]
# INITIAL_CALL_TYPE                         object
# INITIAL_SEVERITY_LEVEL_CODE                int64
# FINAL_CALL_TYPE                           object
# FINAL_SEVERITY_LEVEL_CODE                  int64
# FIRST_ASSIGNMENT_DATETIME                 object
# VALID_DISPATCH_RSPNS_TIME_INDC            object
# DISPATCH_RESPONSE_SECONDS_QY               int64
# FIRST_ACTIVATION_DATETIME                 object
# FIRST_ON_SCENE_DATETIME                   object
# VALID_INCIDENT_RSPNS_TIME_INDC            object
# INCIDENT_RESPONSE_SECONDS_QY             float64
# INCIDENT_TRAVEL_TM_SECONDS_QY            float64
# FIRST_TO_HOSP_DATETIME                    object
# FIRST_HOSP_ARRIVAL_DATETIME               object
# INCIDENT_CLOSE_DATETIME                   object
# HELD_INDICATOR                            object
# INCIDENT_DISPOSITION_CODE                float64
# BOROUGH                                   object
# INCIDENT_DISPATCH_AREA                    object
# ZIPCODE                                  float64
# POLICEPRECINCT                           float64
# CITYCOUNCILDISTRICT                      float64
# COMMUNITYDISTRICT                        float64
# COMMUNITYSCHOOLDISTRICT                  float64
# CONGRESSIONALDISTRICT                    float64
# REOPEN_INDICATOR                          object
# SPECIAL_EVENT_INDICATOR                   object
# STANDBY_INDICATOR                         object
# TRANSFER_INDICATOR                        object
# day                                      float64
# month                                    float64
# dtype: object

# %%
#example = ems.iloc[53]
#example['INCIDENT_DATETIME'].hour

def getDay(date):
    return date.day

ems['day']=ems['INCIDENT_DATETIME'].apply(getDay)

def getMonth(date):
    return date.month

ems['month']=ems['INCIDENT_DATETIME'].apply(getMonth)

def getYear(date):
    return date.year

ems['year']=ems['INCIDENT_DATETIME'].apply(getYear)

# %%
ems.tail(20)
# Out:
#          CAD_INCIDENT_ID   INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 8557828        183651412 2018-12-31 10:37:02             OTHER
# 8557829        183651471 2018-12-31 10:56:53            UNKNOW
# 8557830        183651756 2018-12-31 12:20:00             OTHER
# 8557831        183651960 2018-12-31 13:15:12            INJURY
# 8557832        183652134 2018-12-31 13:56:47             OTHER
# 8557833        183652281 2018-12-31 14:29:23             OTHER
# 8557834        183652312 2018-12-31 14:36:05            UNKNOW
# 8557835        183652325 2018-12-31 14:38:49            UNKNOW
# 8557836        183652545 2018-12-31 15:41:11             OTHER
# 8557837        183652774 2018-12-31 16:44:11               EDP
# 8557838        183652967 2018-12-31 17:36:39             SEIZR
# 8557839        183653206 2018-12-31 18:51:34             OTHER
# 8557840        183653378 2018-12-31 19:38:45             OTHER
# 8557841        183653711 2018-12-31 21:05:42              SICK
# 8557842        183653757 2018-12-31 21:17:46            INJURY
# 8557843        183653775 2018-12-31 21:22:44             OTHER
# 8557844        183653969 2018-12-31 22:12:43              SHOT
# 8557845        183654050 2018-12-31 22:33:43             OTHER
# 8557846        183654167 2018-12-31 23:00:43             OTHER
# 8557847        183654276 2018-12-31 23:31:55            UNKNOW
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 8557828                            6           OTHER
# 8557829                            4          UNKNOW
# 8557830                            6           OTHER
# 8557831                            5          INJURY
# 8557832                            6           OTHER
# 8557833                            6           OTHER
# 8557834                            4          INJURY
# 8557835                            4          UNKNOW
# 8557836                            6           OTHER
# 8557837                            7             EDP
# 8557838                            3           SEIZR
# 8557839                            6           OTHER
# 8557840                            6           OTHER
# 8557841                            6            SICK
# 8557842                            5          INJURY
# 8557843                            6           OTHER
# 8557844                            3            SHOT
# 8557845                            6           OTHER
# 8557846                            6           OTHER
# 8557847                            4          UNKNOW
#
#          FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
#
PECIAL_EVENT_INDICATOR STANDBY_INDICATOR TRANSFER_INDICATOR day  \
# 8557828                       N                 N                  N  31
# 8557829                       N                 N                  N  31
# 8557830                       N                 N                  N  31
# 8557831                       N                 N                  N  31
# 8557832                       N                 N                  N  31
# 8557833                       N                 N                  N  31
# 8557834                       N                 N                  N  31
# 8557835                       N                 N                  N  31
# 8557836                       N                 N                  N  31
# 8557837                       N                 N                  N  31
# 8557838                       N                 N                  N  31
# 8557839                       N                 N                  N  31
# 8557840                       N                 N                  N  31
# 8557841                       N                 N                  N  31
# 8557842                       N                 N                  N  31
# 8557843                       N                 N                  N  31
# 8557844                       N                 N                  N  31
# 8557845                       N                 N                  N  31
# 8557846                       N                 N                  N  31
# 8557847                       N                 N                  N  31
#
#          month  year
# 8557828     12  2018
# 8557829     12  2018
# 8557830     12  2018
# 8557831     12  2018
# 8557832     12  2018
# 8557833     12  2018
# 8557834     12  2018
# 8557835     12  2018
# 8557836     12  2018
# 8557837     12  2018
# 8557838     12  2018
# 8557839     12  2018
# 8557840     12  2018
# 8557841     12  2018
# 8557842     12  2018
# 8557843     12  2018
# 8557844     12  2018
# 8557845     12  2018
# 8557846     12  2018
# 8557847     12  2018
#
# [20 rows x 34 columns]

# %%
#ems2016= ems["INCIDENT_DATETIME"]
#ems2016.dtypes
# Out:
# dtype('O')

# %%
ems2016 = ems[(ems['year']>2016) & (ems['year']<2019)]
ems2016.head()
# Out:
#          CAD_INCIDENT_ID   INCIDENT_DATETIME INITIAL_CALL_TYPE  \
# 5527474        170010907 2017-01-01 02:34:02               EDP
# 5527608        170011205 2017-01-01 03:28:49            INJURY
# 5527721        170011285 2017-01-01 03:43:55               EDP
# 5527946        170011431 2017-01-01 04:12:29            INJURY
# 5528217        170011432 2017-01-01 04:12:37              CARD
#
#          INITIAL_SEVERITY_LEVEL_CODE FINAL_CALL_TYPE  \
# 5527474                            7             EDP
# 5527608                            5            DRUG
# 5527721                            7             EDP
# 5527946                            5          INJURY
# 5528217                            3            CARD
#
#          FINAL_SEVERITY_LEVEL_CODE FIRST_ASSIGNMENT_DATETIME  \
# 5527474                          7                       NaN
# 5527608                          4    01/01/2017 03:31:02 AM
# 5527721                          7                       NaN
# 5527946                          5    01/01/2017 04:15:29 AM
# 5528217                          3    01/01/2017 04:12:55 AM
#
#         VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 5527474                              N                             0
# 5527608                              Y                           133
# 5527721                              N                             0
# 5527946                              Y                           180
# 5528217                              Y                            18
#
#         FIRST_ACTIVATION_DATETIME  ... COMMUNITYDISTRICT  \
# 5527474                       NaN  ...             202.0
# 5527608    01/01/2017 03:31:45 AM  ...               NaN
# 5527721                       NaN  ...             210.0
# 5527946    01/01/2017 04:15:44 AM  ...             205.0
# 5528217    01/01/2017 04:13:09 AM  ...             203.0
#
#         COMMUNITYSCHOOLDISTRICT  CONGRESSIONALDISTRICT  REOPEN_INDICATOR  \
# 5527474                     8.0                   15.0                 N
# 5527608                     NaN                    NaN                 N
# 5527721                    11.0                   16.0                 N
# 5527946                     9.0                   13.0                 N
# 5528217                    12.0                   15.0                 N
#
#         SPECIAL_EVENT_INDICATOR STANDBY_INDICATOR TRANSFER_INDICATOR day  \
# 5527474                       N                 N                  N   1
# 5527608                       N                 N                  N   1
# 5527721                       N                 N                  N   1
# 5527946                       N                 N                  N   1
# 5528217                       N                 N                  N   1
#
#          month  year
# 5527474      1  2017
# 5527608      1  2017
# 5527721      1  2017
# 5527946      1  2017
# 5528217      1  2017
#
# [5 rows x 34 columns]

# %%
ems['INCIDENT_DATETIME']= pd.date_range('2018')
